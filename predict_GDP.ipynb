# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import re
import json
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Data/GDP.csv')
Countries = []
Countries = df['CountryID'].unique()
Years = [2021,2022,2023,2024,2025,2026,2027,2028,2029,2030]
Years
country_l = []
GDP = []
Year_Final = []
Income_Level = []

# %%
for Country in Countries:
    df = pd.read_csv('Data/GDP.csv')
    df = df.loc[df['CountryID'] == Country]
    print(f"Country: {Country}")
    X = df["Year"].values.reshape(-1, 1)
    y = df["GDP_Per_Capita"].values.reshape(-1, 1)
    print("Shape: ", X.shape, y.shape)
    
    # Use sklearn's `train_test_split` to split the data into training and testing
    from sklearn.model_selection import train_test_split
    
    ### BEGIN SOLUTION
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    ### END SOLUTION
    
    # Create the model
    ### BEGIN SOLUTION
    from sklearn.linear_model import LinearRegression
    model = LinearRegression()
    ### END SOLUTION
    
    # Fit the model to the training data. 
    ### BEGIN SOLUTION
    model.fit(X_train, y_train)
    ### END SOLUTION
    
    # Calculate the mean_squared_error and the r-squared value
    # for the testing data
    
    from sklearn.metrics import mean_squared_error, r2_score
    
    ### BEGIN SOLUTION
    
    # Use our model to make predictions
    predicted = model.predict(X_test)
    
    # Score the predictions with mse and r2
    mse = mean_squared_error(y_test, predicted)
    r2 = r2_score(y_test, predicted)

    print(f"Mean Squared Error (MSE): {mse}")
    print(f"R-squared (R2 ): {r2}")
    
    ### END SOLUTION
    # Call the `score` method on the model to show the r2 score
    
    ### BEGIN SOLUTION
    model.score(X_test, y_test)
    ### END SOLUTION
    
    for year in Years:
        result = int(model.coef_[0][0] * year + model.intercept_[0])
        country_l.append(Country.upper())
        GDP.append(result)
        Year_Final.append(year)
        Income = ""
        
        if (result > 0) and (result <= 1046):
            Income = "Low Income"
        elif (result > 1046) and (result <= 4095):
            Income = "Low-Middle Income"
        elif (result > 4095) and (result <= 12695):
            Income = "Upper-Middle Income"
        else:
            Income = "High Income"
        
        Income_Level.append(Income)
        print(f"GDP for {Country.upper()} the year {year} will be {result:,d} and Income Level is {Income}")
# Out:
# Country: ABW
# Shape:  (30, 1) (30, 1)
# Mean Squared Error (MSE): 1464619.964089505
# R-squared (R2 ): 0.8945042345979622
# GDP for ABW the year 2021 will be 30,137 and Income Level is High Income
# GDP for ABW the year 2022 will be 30,694 and Income Level is High Income
# GDP for ABW the year 2023 will be 31,251 and Income Level is High Income
# GDP for ABW the year 2024 will be 31,807 and Income Level is High Income
# GDP for ABW the year 2025 will be 32,364 and Income Level is High Income
# GDP for ABW the year 2026 will be 32,921 and Income Level is High Income
# GDP for ABW the year 2027 will be 33,478 and Income Level is High Income
# GDP for ABW the year 2028 will be 34,035 and Income Level is High Income
# GDP for ABW the year 2029 will be 34,592 and Income Level is High Income
# GDP for ABW the year 2030 will be 35,149 and Income Level is High Income
# Country: AFG
# Shape:  (12, 1) (12, 1)
# Mean Squared Error (MSE): 7690.855986600444
# R-squared (R2 ): -5.071728410474035
# ...

# %%
# # Plot the data to see if a linear trend exists

# ### BEGIN SOLUTION
# plt.scatter(X, y)
# plt.xlabel("Year")
# plt.ylabel("Population")
# plt.show()
# ### END SOLUTION

# %%
#Combine all the lists into one export dataframe and export to CSV

master_df = pd.DataFrame({'CountryID':country_l,'Year':Year_Final,'GDP_Per_Capita':GDP, 'Income_Level':Income_Level})
master_df.to_csv("Data/GDP_Forecast.csv")

# %%
master_df
# Out:
#      CountryID  Year  GDP_Per_Capita       Income_Level
# 0          ABW  2021           30137        High Income
# 1          ABW  2022           30694        High Income
# 2          ABW  2023           31251        High Income
# 3          ABW  2024           31807        High Income
# 4          ABW  2025           32364        High Income
# ...        ...   ...             ...                ...
# 2015       ZWE  2026            1129  Low-Middle Income
# 2016       ZWE  2027            1144  Low-Middle Income
# 2017       ZWE  2028            1159  Low-Middle Income
# 2018       ZWE  2029            1173  Low-Middle Income
# 2019       ZWE  2030            1188  Low-Middle Income
#
# [2020 rows x 4 columns]
